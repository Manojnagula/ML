# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipeline.pkl','rb'))

# %%
test_input = np.array([50,'female',31.0,1,0,10.5,'s'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# c:\Users\Manoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\Manoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
